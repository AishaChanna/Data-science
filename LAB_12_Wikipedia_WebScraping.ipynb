# %% [markdown]
# <a href="https://colab.research.google.com/github/AishaChanna/Data-science/blob/main/LAB_12_Wikipedia_WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB# 12
# ROLNO: 20SW122
# SECTION: 2

# %%
import requests

# Fetch a web page
r = requests.get("https://www.dawn.com/")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#     <!-- meta -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
#     <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
#     <title>Home - DAWN.COM</title>
#      <meta name='subject' content='Your window to latest news, analysis and features from Pakistan, South Asia and the world.' />
#      <meta name='description' content='Checkout for the Latest and Top News from Pakistan and around the world' />
#      <meta property='fb:app_id' content='1383068068604634' />
#      <meta property='og:locale' content='en_US' />
#      <link rel='canonical' href='https://www.dawn.com/' />
#
#      <link rel='index' href='https://www.dawn.com/' />
#      <meta name='twitter:image' content='https://www.dawn.com/_img/social-default.jpg' />
#      <meta property='og:image' content='https://www.dawn.com/_img/social-default.jpg' />
# ...

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Data - Wikipedia
# ...

# %%
from bs4 import BeautifulSoup

# %%
# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Data - Wikipedia
# ...

# %%
#mw-content-container
# Find all articles
summaries = soup.find_all("div", class_="hatnote navigation-not-searchable")
summaries[0]
# Out:
# <div class="hatnote navigation-not-searchable" role="note">"Scientific data" redirects here. Not to be confused with <a href="/wiki/Scientific_Data_(journal)" title="Scientific Data (journal)"><i>Scientific Data</i> (journal)</a>.</div>

# %%
summaries[0].get_text().strip()
# Out:
# '"Scientific data" redirects here. Not to be confused with Scientific Data (journal).'
